# %% [markdown]
# # Page Rank and HITS

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.xkcd()
import networkx as nx
# %matplotlib inline

# %% [markdown]
# During with lab we will check the change of results of Page Rank and HITS algorithms with respect to the values of $\alpha$ and number of iterations.

# %% [markdown]
# ### Task 1.

# %% [markdown]
# a) Firstly let's make experiment for small network (Zachary or any other small one). Set any 3 distinct values for $\alpha$, fix the number of iterations, and run Page Rank. Plot results PR values wrt $\alpha$

# %%
G = nx.karate_club_graph()

fig = plt.figure(1,figsize=(7,7))
ax = plt.subplot(111)

alphas = np.arange(0.1,0.9,0.2)

for alp in alphas:
    pr = nx.pagerank(G, alpha=alp)
    prval = pr.values()
    ax.plot(prval,c = np.random.rand(3,1),label='alpha {0:.2f}'.format(alp))

ax.legend()

# %%
nx.draw(G)

# %% [markdown]
# b) Do the same for the number of iterations

# %% [markdown]
# c) Plot Page-Rank vs. Degree centrality

# %%
pr = nx.pagerank(G,alpha=0.8)
pr = pr.values()
d = nx.degree_centrality(G)
d = d.values()

plt.plot(d,pr, '*')
plt.xlabel('Degree Centrality')
plt.ylabel('Page-rank')

# %% [markdown]
# ### Task 2.

# %% [markdown]
# Let's switch to a bigger network. Download [political blogs](http://networkdata.ics.uci.edu/data/polblogs/polblogs.gml) network. Check its basic properties. Run HITS algorithm. Try to inverstigate the top nodes.

# %%
import urllib

URL = 'http://networkdata.ics.uci.edu/data/polblogs/polblogs.gml'

f = urllib.urlopen(URL)
myfile = f.read()

# %%
G = nx.read_gml('polblogs.gml')

# %%
G.is_directed()
A = nx.adjacency_matrix(G)

P = nx.DiGraph(A)

# %%
(h,a) = nx.hits(P)
a = a.values()
h = h.values()

# %%
plt.plot(h,a,'*')
plt.xlabel('Hubs')
plt.ylabel('Auth')

# %%
idx = np.argsort(a)
idx[-3]
# Out:
# 714

# %%
G.nodes[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-68bf7cabb2ad> in <module>()
# ----> 1 G.nodes[0]
#
# /home/sclab/Desktop/network/.env/local/lib/python2.7/site-packages/networkx/classes/reportviews.pyc in __getitem__(self, n)
#     176
#     177     def __getitem__(self, n):
# --> 178         return self._nodes[n]
#     179
#     180     # Set methods
#
# KeyError: 0

# %%
? G.node
